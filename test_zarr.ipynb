# %%
import numpy as np, zarr, openslide, PIL
from PIL import Image
PIL.Image.MAX_IMAGE_PIXELS = None
import matplotlib.pyplot as plt

# %%
arr = (np.random.randn(10000, 5000) > 0)
arr = arr.astype(bool)
arr.shape
# Out:
# (10000, 5000)

# %%
zarr.save('example.zarr', arr)

# %%
pos_x = 25_000
pos_y = 20_000

# %%
zarr_label = zarr.open('/local/scratch/clmn1/data/AGGC2/AGGC2022_train/Subset1_Train_annotations/Subset1_Train_7/G3_Mask.zarr')

# %%
plt.imshow(zarr_label[pos_y:pos_y+10_000, pos_x:pos_x+10_000])

# %%
#40320, 60480
openslide_file = openslide.open_slide("/local/scratch/AGGC/AGGC2022_train/Subset1_Train_image/Subset1_Train_7.tiff")
openslide_img = openslide_file.read_region((pos_x, pos_y), 0, (10_000, 10_000))

# %%
openslide_file.level_dimensions
# Out:
# ((40320, 60480),)

# %%
plt.imshow(np.array(openslide_img))

# %%
img = Image.open("/local/scratch/AGGC/AGGC2022_train/Subset1_Train_annotations/Subset1_Train_7/G3_Mask.tif")

# %%
print(img.size)
img = np.array(img)
print(img.shape)
# Out:
# (40320, 60480)
# (60480, 40320)

# %%
plt.imshow(img)
